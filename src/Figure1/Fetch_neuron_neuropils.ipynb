# %%
from fafbseg import flywire
import navis
import numpy as np

#flywire.set_chunkedgraph_secret("6e085c31639959b57fc2e8cd3500cbc7")

# %% [markdown]
# # Fetch neurons(change the root id)

# %%
LC9 = flywire.get_mesh_neuron(720575940621807599)
_ = flywire.get_synapses(LC9, attach=True)
#LC9.plot3d()

# %%
# optional split
split = navis.split_axon_dendrite(LC9, metric='synapse_flow_centrality',  reroot_soma=True)
_ = split.plot3d(color=split.color)
# fragments: axon = red, dendrites = blue, CBF = green

# %%
#save
import numpy as np
np.savetxt("720575940621807599_cLM01_vertices.csv", LC9.vertices, delimiter=",")
np.savetxt("720575940621807599_cLM01_faces.csv", LC9.faces, delimiter=",")

# %% [markdown]
# # Fetch neuropils

# %%
Me_L = flywire.get_neuropil_volumes('ME_L')
np.savetxt("Me_L_vertices.csv", Me_L.vertices, delimiter=",")
np.savetxt("Me_L_faces.csv", Me_L.faces, delimiter=",")

# %%
Me_R = flywire.get_neuropil_volumes('ME_R')
np.savetxt("Me_R_vertices.csv", Me_R.vertices, delimiter=",")
np.savetxt("Me_R_faces.csv", Me_R.faces, delimiter=",")

# %%
Lo_R = flywire.get_neuropil_volumes('LO_R')
np.savetxt("Lo_R_vertices.csv", Lo_R.vertices, delimiter=",")
np.savetxt("Lo_R_faces.csv", Lo_R.faces, delimiter=",")

# %%
Lo_L = flywire.get_neuropil_volumes('LO_L')
np.savetxt("Lo_L_vertices.csv", Lo_L.vertices, delimiter=",")
np.savetxt("Lo_L_faces.csv", Lo_L.faces, delimiter=",")

# %%
LoP_R = flywire.get_neuropil_volumes('LOP_R')
np.savetxt("LoP_R_vertices.csv", LoP_R.vertices, delimiter=",")
np.savetxt("LoP_R_faces.csv", LoP_R.faces, delimiter=",")

# %%
LoP_L = flywire.get_neuropil_volumes('LOP_L')
np.savetxt("LoP_L_vertices.csv", LoP_L.vertices, delimiter=",")
np.savetxt("LoP_L_faces.csv", LoP_L.faces, delimiter=",")

# %%
AMe_L = flywire.get_neuropil_volumes('AME_L')
np.savetxt("AMe_L_vertices.csv", AMe_L.vertices, delimiter=",")
np.savetxt("AMe_L_faces.csv", AMe_L.faces, delimiter=",")

# %%
AMe_R = flywire.get_neuropil_volumes('AME_R')
np.savetxt("AMe_R_vertices.csv", AMe_R.vertices, delimiter=",")
np.savetxt("AMe_R_faces.csv", AMe_R.faces, delimiter=",")
